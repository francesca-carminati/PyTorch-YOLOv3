# %%
from PIL import Image
 
# Opens a image in RGB mode
im = Image.open(r"/home/francesca.carminati/repo/PyTorch-YOLOv3/YOLO_test_imgs/cat.jpeg")

# %%
im.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x320 at 0x7F1104028A90>

# %%
im1 = im
newsize = (256, 256)
im1 = im1.resize(newsize)
# Shows the image in image viewer
im1.show()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F1104CDEF70>

# %%
im1.save
